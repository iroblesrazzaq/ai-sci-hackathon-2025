# %% [markdown]
# This jupyter notebook teaches you how to interact with the real neuronal networks (static state function).
#
# Before you run this code, set your group_id and password in "auth.py". Ask your mentor for your password/id.

# %%
import gymnasium as gym
import numpy as np

# Add parent directory to path
import sys
from pathlib import Path
current_dir = Path().resolve()
root_dir = current_dir.parent
if str(root_dir) not in sys.path:
    sys.path.insert(0,str(root_dir))

from Gyms.RealNetworkSync import RealNetworkSync

# %%
# Define size of state and action spaces, as well as stimulation period
state_dim   = 4   # Dimension of reduced state space
action_dim  = 5   # Number of stimuli in action space
circuit_id  = 0   # Each group has 4 biological/simulated circuits. You choose here which one you want to use. Must be in {0,1,2,3}

# %%
# Create environment and initialize it
from Reward.TrainingReward import TrainingReward
env      = RealNetworkSync(action_dim=action_dim,state_dim=state_dim,circuit_id=circuit_id)
state, _ = env.reset()
env.render() # This function gives you the current state + reward, which both is 0 after initialization
# Out:
# Host/Port open and accessable
# Current state: [0. 0. 0. 0.], Reward: 0

# %%
from Algorithms.MultiArmedBandit import MABAgent  # Update path if needed

# Initialize MAB agent
agent = MABAgent(
    epsilon=0.9,            # Initial exploration rate (90% random actions)
    alpha=0.1,              # Learning rate (constant step-size)
    initial_q=0.0,          # Optimistic initial values
    n_actions=125,           # Number of actions, should be a power of 5
)

# %%
from tqdm import tqdm
# Example code, that stimulates the network 100 times with a randomly sampled action, while calculating also the average reward received

total_reward = 0
action_count = 0

rewards_over_time = []

for _ in range(100):
    action_idx = agent.select_action()
    action = agent.action_map(action_idx)
    print(f"Stimulate with action: {action}")
    
    state, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    action_count += 1

    rewards_over_time.append(reward)

    agent.update(action_idx, reward)

    # Plot information
    print(f"Info: {info}")
    print(f"State: {state}, Reward: {reward}")

    print("-----------------------------")
# Out:
# Stimulate with action: [0 0 1 0 0]
# Info: {'spikes': array([ 0.4,  0.5,  1.5,  2.2,  4. ,  4.1,  4.6,  6. ,  6. ,  8.2,  8.5,
#        10.4, 11. , 11.3, 12.1, 12.1, 13.5, 16.6, 16.9, 17.9]), 'elecs': array([1., 2., 3., 3., 0., 1., 2., 2., 0., 3., 0., 1., 2., 2., 2., 0., 3.,
#        1., 0., 3.]), 'action': array([0, 0, 1, 0, 0]), 'missed_cyc': 0, 'stim_id': 4313, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.06324555 -0.2         0.        ], Reward: 3
# -----------------------------
# Stimulate with action: [0 0 1 4 2]
# Info: {'spikes': array([], dtype=float64), 'elecs': array([], dtype=float64), 'action': array([0, 0, 1, 4, 2]), 'missed_cyc': 0, 'stim_id': 4314, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 0
# -----------------------------
# Stimulate with action: [0 0 3 3 0]
# Info: {'spikes': array([ 1.7,  1.8,  2.8,  3.1,  3.3,  4. ,  4. ,  5.3,  5.7,  7.6,  8.1,
#         8.2,  8.6, 11. , 13. , 17.6]), 'elecs': array([1., 1., 3., 0., 2., 2., 0., 3., 0., 1., 1., 2., 2., 3., 0., 0.]), 'action': array([0, 0, 3, 3, 0]), 'missed_cyc': 0, 'stim_id': 4315, 'simulated': False, 'comment': 'none'}
# State: [-0.5  0.   0.   0. ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 0 3 1]
# Info: {'spikes': array([ 0.1,  2.1,  2.6,  2.7,  3.6,  3.8,  4. ,  5.3,  5.6,  7.7, 11.5,
#        16.1, 17.4]), 'elecs': array([3., 1., 2., 1., 2., 0., 3., 0., 3., 0., 2., 1., 3.]), 'action': array([0, 0, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 4316, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.14142136  0.        ], Reward: 0
# -----------------------------
# Stimulate with action: [0 0 4 4 1]
# Info: {'spikes': array([ 0.4,  4.1,  6. ,  8.1, 10.2, 11.2, 11.7, 13.1, 15. , 15.1, 15.5,
#        16.7, 17.1, 17.8, 18.9, 19.1]), 'elecs': array([3., 0., 2., 0., 1., 2., 3., 3., 1., 0., 2., 2., 2., 0., 3., 0.]), 'action': array([0, 0, 4, 4, 1]), 'missed_cyc': 0, 'stim_id': 4317, 'simulated': False, 'comment': 'none'}
# State: [ 0.5        -0.38470768  0.          0.        ], Reward: 2
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.1,  1.9,  2.1,  4.2,  4.7,  5.1,  5.6,  7.5,  9.1, 10.9, 13. ,
#        15.1, 16.5]), 'elecs': array([2., 3., 0., 1., 2., 2., 3., 3., 0., 2., 0., 1., 3.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4318, 'simulated': False, 'comment': 'none'}
# State: [ 0.         -0.26832816 -0.08944272  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 0 2 3]
# Info: {'spikes': array([ 2.8,  4.5,  6.6,  8.6,  9.6,  9.9, 11.5, 13.4, 13.5, 13.9, 15.1,
#        15.2, 16.4, 17.2, 17.3, 19.2, 19.6]), 'elecs': array([0., 2., 0., 1., 2., 3., 3., 0., 1., 2., 2., 2., 0., 0., 3., 1., 1.]), 'action': array([0, 0, 0, 2, 3]), 'missed_cyc': 0, 'stim_id': 4319, 'simulated': False, 'comment': 'none'}
# State: [-1.  0.  0.  0.], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 0 4 3]
# Info: {'spikes': array([ 1.3,  1.8,  2.3,  2.5,  2.9,  5.2,  6. ,  7.6,  9.8, 11.8, 13.1,
#        16.6, 18.3]), 'elecs': array([1., 1., 2., 3., 2., 3., 0., 2., 0., 1., 3., 0., 2.]), 'action': array([0, 0, 0, 4, 3]), 'missed_cyc': 0, 'stim_id': 4320, 'simulated': False, 'comment': 'none'}
# State: [-0.5         0.         -0.14142136  0.        ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1.9,  3.9,  4.9,  5.1,  6.8,  8.7,  8.8,  9.2, 10.3, 10.7, 11.6,
#        12.4, 12.8, 14.4, 15.2, 15.6, 15.7, 19. ]), 'elecs': array([0., 1., 2., 3., 3., 0., 1., 2., 2., 2., 0., 0., 3., 1., 1., 3., 2.,
#        0.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4321, 'simulated': False, 'comment': 'none'}
# State: [-1.         -0.28284271 -0.2         0.        ], Reward: 3
# -----------------------------
# Stimulate with action: [0 0 2 3 2]
# Info: {'spikes': array([ 0.3,  1.8,  3.9,  5.9,  6.7,  7.1,  8.3, 10.2, 10.6, 10.6, 12.2,
#        13.2, 14.1, 16.2, 17.4]), 'elecs': array([0., 2., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 3.]), 'action': array([0, 0, 2, 3, 2]), 'missed_cyc': 0, 'stim_id': 4322, 'simulated': False, 'comment': 'none'}
# State: [-1.  0.  0.  0.], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.4,  0.7,  1.6,  3.1,  3.1,  5.2,  7.2,  8.4, 11.9, 13.4, 15.5,
#        17.5, 18.2, 18.7, 19.8]), 'elecs': array([1., 2., 0., 0., 2., 0., 1., 3., 0., 2., 0., 1., 2., 3., 3.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4323, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 4 0 3]
# Info: {'spikes': array([ 0.9,  2.9,  2.9,  3.3,  4.4,  6.2,  6.3,  8.4,  9.5, 13.1, 14.6,
#        16.6, 18.6, 19.3, 19.7]), 'elecs': array([3., 0., 1., 2., 2., 0., 0., 1., 3., 0., 2., 0., 1., 2., 3.]), 'action': array([0, 0, 4, 0, 3]), 'missed_cyc': 0, 'stim_id': 4324, 'simulated': False, 'comment': 'none'}
# State: [ 0.5        -0.28284271 -0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 2 1 4]
# Info: {'spikes': array([ 3.6,  5.1,  7. ,  9.1,  9.7, 10.2, 11.3, 13.2, 13.6, 13.7, 15.2,
#        16.1, 17.1, 19.2]), 'elecs': array([0., 2., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.]), 'action': array([0, 0, 2, 1, 4]), 'missed_cyc': 0, 'stim_id': 4325, 'simulated': False, 'comment': 'none'}
# State: [-1.  0.  0.  0.], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 1 3 1]
# Info: {'spikes': array([ 0.2,  0.4,  2.1,  2.4,  3.3,  4.8,  4.9,  6.7,  8.8,  9.9, 13.5,
#        15. , 16.9, 19. , 19.5]), 'elecs': array([3., 3., 1., 2., 0., 2., 0., 0., 1., 3., 0., 2., 0., 1., 2.]), 'action': array([0, 0, 1, 3, 1]), 'missed_cyc': 0, 'stim_id': 4326, 'simulated': False, 'comment': 'none'}
# State: [0.5 0.  0.  0. ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1.6,  3.4,  3.6,  4. ,  4.9,  6.8,  8.8,  9.9, 13.4, 14.9, 16.7,
#        18.8, 19.3, 19.9]), 'elecs': array([3., 0., 1., 2., 2., 0., 1., 3., 0., 2., 0., 1., 2., 3.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4327, 'simulated': False, 'comment': 'none'}
# State: [ 0.5        -0.26832816 -0.08944272  0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 2 2 3]
# Info: {'spikes': array([ 1. ,  2.9,  2.9,  3.3,  4.4,  6.1,  6.2,  8.3,  9.4, 13. , 14.4,
#        16.2, 18.3, 18.8, 19.4]), 'elecs': array([3., 0., 1., 2., 2., 0., 0., 1., 3., 0., 2., 0., 1., 2., 3.]), 'action': array([0, 0, 2, 2, 3]), 'missed_cyc': 0, 'stim_id': 4328, 'simulated': False, 'comment': 'none'}
# State: [ 0.5        -0.27568098 -0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1.5,  1.9,  2.3,  3.7,  4.6,  5.5,  7.6,  8.7, 12.2, 13.7, 15.5,
#        17.6, 18.1, 18.7, 19.8]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 3., 0., 2., 0., 1., 2., 3., 3.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4329, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.12649111  0.          0.        ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 4 0 4]
# Info: {'spikes': array([ 0.8,  2.2,  2.2,  4. ,  6.1,  7.2, 10.7, 12.1, 13.9, 16. , 16.5,
#        17. , 18.1, 19.9]), 'elecs': array([0., 0., 2., 0., 1., 3., 0., 2., 0., 1., 2., 3., 3., 1.]), 'action': array([0, 0, 4, 0, 4]), 'missed_cyc': 0, 'stim_id': 4330, 'simulated': False, 'comment': 'none'}
# State: [-1.  0.  0.  0.], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1. ,  1.4,  2.8,  4.9,  5.8,  6. ,  7.7,  9.5,  9.6, 10. , 10.9,
#        12.6, 14.7, 15.8, 19.3]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 0., 1., 2., 2., 0., 1., 3., 0.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4331, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.1,  1.8,  3.9,  4.3,  4.9,  6. ,  7.8,  8.1,  8.4,  9.8, 10.6,
#        11.6, 13.7, 14.5, 14.7, 16.4, 18.3, 18.3, 18.7, 19.7]), 'elecs': array([2., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1.,
#        0., 2., 2.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4332, 'simulated': False, 'comment': 'none'}
# State: [ 0.          0.         -0.28982753  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 2 3 4]
# Info: {'spikes': array([ 0.3,  2.4,  3.4,  7. ,  8.4, 10.1, 12.2, 12.6, 13.2, 14.3, 16.1,
#        16.4, 16.7, 18.1, 18.9, 19.8]), 'elecs': array([0., 1., 3., 0., 2., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.]), 'action': array([0, 0, 2, 3, 4]), 'missed_cyc': 0, 'stim_id': 4333, 'simulated': False, 'comment': 'none'}
# State: [-1.         -0.28982753  0.          0.        ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 3 2 3]
# Info: {'spikes': array([ 1. ,  1.5,  1.9,  2. ,  3.2,  4.7,  4.8,  6.5,  8.6,  9.6,  9.7,
#        11.5, 13.2, 13.4, 13.8, 14.6, 16.4, 16.5, 18.5, 19.6]), 'elecs': array([1., 1., 2., 3., 0., 2., 0., 0., 1., 2., 3., 3., 0., 1., 2., 2., 0.,
#        0., 1., 3.]), 'action': array([0, 0, 3, 2, 3]), 'missed_cyc': 0, 'stim_id': 4334, 'simulated': False, 'comment': 'none'}
# State: [-0.5         0.         -0.12649111  0.        ], Reward: 10
# -----------------------------
# Stimulate with action: [0 0 0 1 3]
# Info: {'spikes': array([ 0.8,  2.4,  2.7,  3.1,  3.8,  5.5,  5.8,  7.6,  8.6, 12.2, 13.6,
#        15.3, 17.4, 17.8, 18.4, 19.5]), 'elecs': array([3., 0., 1., 2., 2., 0., 0., 1., 3., 0., 2., 0., 1., 2., 3., 3.]), 'action': array([0, 0, 0, 1, 3]), 'missed_cyc': 0, 'stim_id': 4335, 'simulated': False, 'comment': 'none'}
# State: [ 0.5        -0.25298221 -0.10954451  0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.2,  0.5,  0.9,  2.3,  2.8,  4. ,  6.1,  6.8,  7.1,  8.6, 10.4,
#        10.6, 10.8, 12. , 13.3, 13.7, 15.8, 16.8]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 0., 2., 2., 0., 0., 1.,
#        3.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4336, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 3
# -----------------------------
# Stimulate with action: [0 0 1 0 4]
# Info: {'spikes': array([ 0.8,  2.5,  4.6,  5. ,  5.6,  6.7,  8.5,  8.8,  9. , 10.4, 11.2,
#        12.1, 14.2, 14.9, 15.2, 16.7, 18.5, 18.7, 18.8]), 'elecs': array([2., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1.,
#        0., 2.]), 'action': array([0, 0, 1, 0, 4]), 'missed_cyc': 0, 'stim_id': 4337, 'simulated': False, 'comment': 'none'}
# State: [ 0.          0.         -0.28982753  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 4 2 3]
# Info: {'spikes': array([ 0.6,  0.8,  2.9,  3.9,  7.5,  8.9, 10.6, 12.7, 13.1, 13.7, 14.8,
#        16.5, 16.8, 17.1, 18.5, 19.2]), 'elecs': array([0., 0., 1., 3., 0., 2., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0.]), 'action': array([0, 0, 4, 2, 3]), 'missed_cyc': 0, 'stim_id': 4338, 'simulated': False, 'comment': 'none'}
# State: [-1.          0.         -0.28982753  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 2 3 2]
# Info: {'spikes': array([ 1.5,  1.8,  2.5,  3.5,  5.3,  5.6,  5.9,  7.3,  8. ,  9. , 11.1,
#        11.8, 12.1, 13.6, 15.4, 15.6, 15.7, 17. , 18.3, 18.7]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 0., 2.,
#        2., 0., 0.]), 'action': array([0, 0, 2, 3, 2]), 'missed_cyc': 0, 'stim_id': 4339, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451 -0.16733201  0.        ], Reward: 4
# -----------------------------
# Stimulate with action: [0 0 0 2 2]
# Info: {'spikes': array([ 0.3,  0.3,  2.1,  3.9,  3.9,  4.2,  5.3,  6.7,  7. ,  9.1, 10. ,
#        10.1, 11.9, 13.7, 13.7, 14. , 15.1, 16.7, 16.8, 18.9, 19.9]), 'elecs': array([2., 3., 3., 0., 1., 2., 2., 0., 0., 1., 2., 3., 3., 1., 0., 2., 2.,
#        0., 0., 1., 3.]), 'action': array([0, 0, 0, 2, 2]), 'missed_cyc': 0, 'stim_id': 4340, 'simulated': False, 'comment': 'none'}
# State: [ 0. -0.  0.  0.], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 1 3 1]
# Info: {'spikes': array([ 1.7,  2. ,  2.2,  3.6,  4.7,  5.3,  7.4,  8.4, 12. , 13.4, 15. ,
#        17.1, 17.5, 18.1, 19.2]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 3., 0., 2., 0., 1., 2., 3., 3.]), 'action': array([0, 0, 1, 3, 1]), 'missed_cyc': 0, 'stim_id': 4341, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 0 0 2]
# Info: {'spikes': array([ 0.4,  1.8,  3.4,  5.5,  5.8,  6.5,  7.5,  9.2,  9.5,  9.9, 11.2,
#        11.9, 12.9, 15. , 15.6, 16. , 17.4, 19.2, 19.5, 19.5]), 'elecs': array([0., 2., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0.]), 'action': array([0, 0, 0, 0, 2]), 'missed_cyc': 0, 'stim_id': 4342, 'simulated': False, 'comment': 'none'}
# State: [-1.  0.  0.  0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1.3,  3.4,  3.7,  4.4,  5.4,  7.1,  7.4,  7.8,  9.2,  9.7, 10.9,
#        13. , 13.6, 14. , 15.4, 17.2, 17.5, 17.5, 18.9]), 'elecs': array([0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 0.,
#        2., 2.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4343, 'simulated': False, 'comment': 'none'}
# State: [-1.         -0.28982753 -0.10954451  0.        ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1. ,  1.3,  2. ,  3. ,  4.7,  5. ,  5.4,  6.8,  7.3,  8.4, 10.5,
#        11. , 11.5, 12.8, 14.6, 14.9, 15. , 16.4, 17.4, 18. ]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4344, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451 -0.16733201  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 1 3 4]
# Info: {'spikes': array([ 1.1,  2.9,  3.2,  3.4,  4.8,  5.9,  6.5,  8.6,  9.5,  9.6, 11.3,
#        13.1, 13.2, 13.4, 14.6, 16. , 16.2, 18.3, 19.1, 19.3]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 0., 2., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 1, 3, 4]), 'missed_cyc': 0, 'stim_id': 4345, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 0 4 0]
# Info: {'spikes': array([ 1.6,  1.7,  1.9,  3.1,  4.6,  4.8,  6.9,  7.7,  7.9,  9.5, 11.3,
#        11.4, 11.6, 12.8, 14.2, 14.4, 16.5, 17.3, 17.5, 19.1]), 'elecs': array([1., 0., 2., 2., 0., 0., 1., 2., 3., 3., 1., 0., 2., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 0, 4, 0]), 'missed_cyc': 0, 'stim_id': 4346, 'simulated': False, 'comment': 'none'}
# State: [-0.5         0.06324555  0.          0.        ], Reward: 5
# -----------------------------
# Stimulate with action: [0 0 3 3 4]
# Info: {'spikes': array([ 0. ,  1.1,  2.6,  2.7,  4.8,  5.6,  5.8,  7.4,  9.2,  9.3,  9.5,
#        10.7, 12.1, 12.3, 14.4, 15.2, 15.4, 17. , 18.8, 18.9, 19.1]), 'elecs': array([2., 2., 0., 0., 1., 2., 3., 3., 1., 0., 2., 2., 0., 0., 1., 2., 3.,
#        3., 1., 0., 2.]), 'action': array([0, 0, 3, 3, 4]), 'missed_cyc': 0, 'stim_id': 4347, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 4
# -----------------------------
# Stimulate with action: [0 0 2 3 0]
# Info: {'spikes': array([ 0.3,  0.4,  2.4,  3.2,  3.4,  5. ,  6.8,  6.9,  7.1,  8.3,  9.8,
#         9.9, 12. , 12.8, 13. , 14.6, 16.4, 16.5, 16.7, 17.9, 19.4, 19.5]), 'elecs': array([0., 0., 1., 2., 3., 3., 1., 0., 2., 2., 0., 0., 1., 2., 3., 3., 1.,
#        0., 2., 2., 0., 0.]), 'action': array([0, 0, 2, 3, 0]), 'missed_cyc': 0, 'stim_id': 4348, 'simulated': False, 'comment': 'none'}
# State: [-1.          0.         -0.28284271  0.        ], Reward: 4
# -----------------------------
# Stimulate with action: [0 0 4 1 1]
# Info: {'spikes': array([ 0.2,  0.8,  1.2,  2.6,  4.4,  4.7,  4.7,  6. ,  7.3,  7.6,  9.7,
#        10.5, 10.7, 12.3, 14.1, 14.3, 14.4, 15.7, 17. , 17.3, 19.4]), 'elecs': array([1., 2., 3., 3., 1., 0., 2., 2., 0., 0., 1., 2., 3., 3., 1., 0., 2.,
#        2., 0., 0., 1.]), 'action': array([0, 0, 4, 1, 1]), 'missed_cyc': 0, 'stim_id': 4349, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.15491933 -0.12649111  0.        ], Reward: 3
# -----------------------------
# Stimulate with action: [0 0 0 1 4]
# Info: {'spikes': array([ 0.6,  2.4,  2.7,  2.7,  4. ,  5.3,  5.6,  7.7,  8.4,  8.7, 10.2,
#        12. , 12.3, 12.3, 13.7, 14.9, 15.3, 17.4, 18.1, 18.4, 19.9]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 0., 2., 2., 0., 0.,
#        1., 2., 3., 3.]), 'action': array([0, 0, 0, 1, 4]), 'missed_cyc': 0, 'stim_id': 4350, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 3 3 0]
# Info: {'spikes': array([ 0.5,  0.8,  0.8,  2.1,  3.4,  3.7,  5.8,  6.5,  6.8,  8.3, 10.1,
#        10.4, 10.4, 11.7, 13. , 13.3, 15.4, 16.1, 16.4, 17.9, 19.7]), 'elecs': array([1., 0., 2., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3., 1.]), 'action': array([0, 0, 3, 3, 0]), 'missed_cyc': 0, 'stim_id': 4351, 'simulated': False, 'comment': 'none'}
# State: [-0.5         0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 4 0 0]
# Info: {'spikes': array([ 0.1,  1.4,  1.7,  3.8,  4.5,  4.8,  6.3,  8.1,  8.4,  8.4,  9.7,
#        11. , 11.3, 13.4, 14.1, 14.4, 15.9, 17.7, 18. , 18. , 19.3]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 1., 0., 2., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0., 2.]), 'action': array([0, 0, 4, 0, 0]), 'missed_cyc': 0, 'stim_id': 4352, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1.3,  2. ,  2.3,  3.8,  5.6,  5.9,  6. ,  7.3,  8.5,  8.9, 11. ,
#        11.7, 12. , 13.5, 15.3, 15.6, 15.7, 17. , 18.2, 18.6]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4353, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.16733201 -0.10954451  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 4 4 4]
# Info: {'spikes': array([ 0.4,  0.4,  2.2,  4. ,  4.3,  4.4,  5.7,  6.9,  7.3,  9.4, 10.1,
#        10.4, 11.9, 13.7, 14. , 14.1, 15.4, 16.6, 17. , 19.1, 19.8]), 'elecs': array([2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2.,
#        0., 0., 1., 2.]), 'action': array([0, 0, 4, 4, 4]), 'missed_cyc': 0, 'stim_id': 4354, 'simulated': False, 'comment': 'none'}
# State: [ 0. -0.  0.  0.], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 0 4 2]
# Info: {'spikes': array([ 0.5,  2.3,  2.6,  2.7,  4. ,  5.2,  5.6,  7.7,  8.3,  8.7, 10.1,
#        11.9, 12.2, 12.4, 13.7, 14.8, 15.3, 17.4, 18. , 18.4, 19.8]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3., 3.]), 'action': array([0, 0, 0, 4, 2]), 'missed_cyc': 0, 'stim_id': 4355, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 1 4 3]
# Info: {'spikes': array([ 0.3,  0.6,  0.9,  2.2,  3.2,  3.8,  5.9,  6.5,  6.9,  8.3, 10.1,
#        10.4, 10.6, 11.9, 13. , 13.5, 15.6, 16.2, 16.6, 18. , 19.8]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3., 1.]), 'action': array([0, 0, 1, 4, 3]), 'missed_cyc': 0, 'stim_id': 4356, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.4,  1.3,  2. ,  4.1,  4.8,  5.1,  6.6,  8.4,  8.7,  8.8, 10.2,
#        11.3, 11.8, 13.9, 14.5, 14.9, 16.3, 18.1, 18.4, 18.6, 19.9]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0., 2.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4357, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 0 4 4]
# Info: {'spikes': array([ 0. ,  0.6,  2.7,  3.3,  3.6,  5.1,  6.9,  7.2,  7.4,  8.7,  9.7,
#        10.3, 12.4, 13. , 13.4, 14.8, 16.6, 16.9, 17.1, 18.4, 19.4]), 'elecs': array([0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1.,
#        2., 0., 2., 0.]), 'action': array([0, 0, 0, 4, 4]), 'missed_cyc': 0, 'stim_id': 4358, 'simulated': False, 'comment': 'none'}
# State: [-1.          0.         -0.28982753  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1. ,  1.6,  2. ,  3.4,  5.2,  5.5,  5.7,  7. ,  8.1,  8.6, 10.7,
#        11.4, 11.6, 13.2, 15. , 15.3, 15.5, 16.8, 17.8, 18.4]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4359, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.15491933 -0.12649111  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 2 2 0]
# Info: {'spikes': array([ 0.2,  0.5,  2. ,  3.8,  4.1,  4.3,  5.6,  6.7,  7.2,  9.3,  9.9,
#        10.3, 11.7, 13.5, 13.8, 14.1, 15.4, 16.3, 17. , 19.1, 19.7]), 'elecs': array([2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2.,
#        0., 0., 1., 2.]), 'action': array([0, 0, 2, 2, 0]), 'missed_cyc': 0, 'stim_id': 4360, 'simulated': False, 'comment': 'none'}
# State: [ 0.         -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 1 1 0]
# Info: {'spikes': array([ 0.8,  2.6,  2.9,  3.2,  4.5,  5.4,  6.1,  8.2,  8.8,  9.1, 10.6,
#        12.4, 12.7, 13. , 14.3, 15.2, 15.9, 18. , 18.6, 19. ]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 1, 1, 0]), 'missed_cyc': 0, 'stim_id': 4361, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 0 4 2]
# Info: {'spikes': array([ 1.4,  1.7,  2. ,  3.3,  4.2,  4.9,  7. ,  7.6,  8. ,  9.4, 11.2,
#        11.5, 11.7, 13. , 14. , 14.6, 16.7, 17.3, 17.7, 19.1]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 0, 4, 2]), 'missed_cyc': 0, 'stim_id': 4362, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 0 0 2]
# Info: {'spikes': array([ 0. ,  0.7,  2. ,  2.6,  3.6,  5.7,  6.3,  6.6,  8.1,  9.9, 10.2,
#        10.5, 11.8, 12.7, 13.4, 15.5, 16.1, 16.4, 17.9, 19.7]), 'elecs': array([2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2.,
#        3., 3., 1.]), 'action': array([0, 0, 0, 0, 2]), 'missed_cyc': 0, 'stim_id': 4363, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 0 4]
# Info: {'spikes': array([ 0.9,  1.9,  2.5,  4.6,  5.2,  5.5,  7. ,  8.8,  9.1,  9.4, 10.7,
#        11.6, 12.3, 14.4, 15. , 15.3, 16.8, 18.6, 18.9, 19.1]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0.]), 'action': array([0, 0, 3, 0, 4]), 'missed_cyc': 0, 'stim_id': 4364, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 4 1 4]
# Info: {'spikes': array([ 0.7,  1.2,  3.3,  3.9,  4.2,  5.7,  7.5,  7.8,  8.1,  9.4, 10.3,
#        11. , 13.1, 13.7, 14. , 15.5, 17.3, 17.6, 17.9, 19.2]), 'elecs': array([0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1.,
#        2., 0., 2.]), 'action': array([0, 0, 4, 1, 4]), 'missed_cyc': 0, 'stim_id': 4365, 'simulated': False, 'comment': 'none'}
# State: [-1.          0.         -0.28982753  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 1 2 4]
# Info: {'spikes': array([ 0. ,  2.1,  2.7,  3.1,  4.5,  6.3,  6.6,  6.9,  8.2,  9.1,  9.8,
#        11.9, 12.5, 12.8, 14.3, 16.1, 16.4, 16.7, 18. , 18.9, 19.6]), 'elecs': array([0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2.,
#        0., 2., 0., 0.]), 'action': array([0, 0, 1, 2, 4]), 'missed_cyc': 0, 'stim_id': 4366, 'simulated': False, 'comment': 'none'}
# State: [-1.         -0.28982753 -0.15491933  0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 3 3]
# Info: {'spikes': array([ 0.9,  1.4,  1.8,  3.2,  5. ,  5.3,  5.7,  7. ,  7.8,  8.6, 10.7,
#        11.3, 11.7, 13.1, 14.9, 15.2, 15.5, 16.8, 17.7, 18.4]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 3, 3, 3]), 'missed_cyc': 0, 'stim_id': 4367, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.14142136 -0.12649111  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.5,  0.8,  2.3,  4.1,  4.4,  4.7,  6. ,  6.9,  7.6,  9.7, 10.3,
#        10.6, 12.1, 13.9, 14.2, 14.5, 15.8, 16.8, 17.4, 19.5]), 'elecs': array([2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2.,
#        0., 0., 1.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4368, 'simulated': False, 'comment': 'none'}
# State: [ 0.         -0.10954451  0.          0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 0 4 1]
# Info: {'spikes': array([ 1.3,  3.1,  3.4,  3.7,  5. ,  5.9,  6.6,  8.7,  9.3,  9.7, 11.1,
#        12.9, 13.2, 13.5, 14.8, 15.7, 16.4, 18.5, 19.1, 19.4]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 0, 4, 1]), 'missed_cyc': 0, 'stim_id': 4369, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 1 0 4]
# Info: {'spikes': array([ 0.1,  1.9,  2.2,  2.6,  3.9,  4.7,  5.5,  7.6,  8.2,  8.6, 10. ,
#        11.8, 12.1, 12.4, 13.7, 14.6, 15.3, 17.4, 18. , 18.3, 19.8]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3., 3.]), 'action': array([0, 0, 1, 0, 4]), 'missed_cyc': 0, 'stim_id': 4370, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 4 2 4]
# Info: {'spikes': array([ 0.9,  1.2,  1.6,  2.9,  3.7,  4.5,  6.6,  7.2,  7.5,  9. , 10.8,
#        11.1, 11.4, 12.7, 13.6, 14.3, 16.4, 17. , 17.3, 18.8]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 4, 2, 4]), 'missed_cyc': 0, 'stim_id': 4371, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 0 3 2]
# Info: {'spikes': array([ 0. ,  0.6,  1.9,  2.5,  3.5,  5.6,  6.2,  6.6,  8. ,  9.8, 10.1,
#        10.4, 11.7, 12.6, 13.3, 15.4, 16. , 16.3, 17.8, 19.6, 19.9]), 'elecs': array([2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2.,
#        3., 3., 1., 2.]), 'action': array([0, 0, 0, 3, 2]), 'missed_cyc': 0, 'stim_id': 4372, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.6,  1.5,  2.2,  4.3,  4.9,  5.3,  6.7,  8.5,  8.8,  9.1, 10.4,
#        11.3, 12. , 14.1, 14.7, 15.1, 16.5, 18.3, 18.6, 18.9]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4373, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 4 0 1]
# Info: {'spikes': array([ 0.2,  1.2,  3.3,  3.9,  4.3,  5.7,  7.5,  7.8,  8.2,  9.5, 10.3,
#        11.1, 13.2, 13.8, 14.2, 15.6, 17.4, 17.7, 18. , 19.3]), 'elecs': array([0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1.,
#        2., 0., 2.]), 'action': array([0, 0, 4, 0, 1]), 'missed_cyc': 0, 'stim_id': 4374, 'simulated': False, 'comment': 'none'}
# State: [-1.          0.         -0.28982753  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 4 1]
# Info: {'spikes': array([ 2. ,  2.5,  2.9,  4.3,  6.1,  6.4,  6.8,  8.1,  8.9,  9.7, 11.8,
#        12.4, 12.7, 14.2, 16. , 16.3, 16.7, 18. , 18.8, 19.6]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 3, 4, 1]), 'missed_cyc': 0, 'stim_id': 4375, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.14142136 -0.12649111  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 4 3 1]
# Info: {'spikes': array([ 1.3,  1.8,  2.2,  3.6,  5.4,  5.7,  6.1,  7.4,  8.2,  9. , 11.1,
#        11.7, 12. , 13.5, 15.3, 15.6, 16. , 17.3, 18.1, 18.9]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 4, 3, 1]), 'missed_cyc': 0, 'stim_id': 4376, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.14142136 -0.12649111  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 4 1 4]
# Info: {'spikes': array([ 0.5,  0.9,  1.4,  2.7,  4.5,  4.8,  5.3,  6.6,  7.3,  8.2, 10.3,
#        10.9, 11.2, 12.7, 14.5, 14.8, 15.2, 16.5, 17.3, 18.1]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 4, 1, 4]), 'missed_cyc': 0, 'stim_id': 4377, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.12649111 -0.14142136  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 0 3 3]
# Info: {'spikes': array([ 0.7,  1.4,  3.2,  3.5,  4.2,  5.5,  6.1,  7.1,  9.2,  9.8, 10.1,
#        11.6, 13.4, 13.7, 14.1, 15.4, 16.2, 17. , 19.1, 19.6]), 'elecs': array([3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0.,
#        0., 1., 2.]), 'action': array([0, 0, 0, 3, 3]), 'missed_cyc': 0, 'stim_id': 4378, 'simulated': False, 'comment': 'none'}
# State: [0.5 0.  0.  0. ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 4 1 0]
# Info: {'spikes': array([ 1.1,  2.9,  3.2,  3.6,  4.9,  5.7,  6.5,  8.6,  9.2,  9.5, 11. ,
#        12.8, 13.1, 13.5, 14.8, 15.6, 16.4, 18.5, 19.1, 19.5]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 4, 1, 0]), 'missed_cyc': 0, 'stim_id': 4379, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 0 4 1]
# Info: {'spikes': array([ 0.6,  2.4,  2.7,  3.1,  4.4,  5.2,  6. ,  8.1,  8.7,  9. , 10.5,
#        12.3, 12.6, 13. , 14.3, 15.1, 15.9, 18. , 18.5, 18.9]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 0, 4, 1]), 'missed_cyc': 0, 'stim_id': 4380, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 1 4]
# Info: {'spikes': array([ 1. ,  1.3,  2. ,  3.3,  3.9,  4.9,  7. ,  7.6,  8. ,  9.4, 11.2,
#        11.5, 11.9, 13.2, 14. , 14.8, 16.9, 17.5, 17.9, 19.3]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 3, 1, 4]), 'missed_cyc': 0, 'stim_id': 4381, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 4 4 1]
# Info: {'spikes': array([ 0.3,  0.6,  1.1,  2.4,  3.1,  4. ,  6.1,  6.7,  7. ,  8.5, 10.3,
#        10.6, 10.9, 12.2, 13.1, 13.8, 15.9, 16.5, 16.8, 18.3]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 4, 4, 1]), 'missed_cyc': 0, 'stim_id': 4382, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 2 0]
# Info: {'spikes': array([ 0.3,  1.6,  2.2,  3.2,  5.3,  5.8,  6.3,  7.6,  9.4,  9.7, 10.1,
#        11.4, 12.2, 13. , 15.1, 15.6, 16.1, 17.4, 19.2, 19.5, 19.9]), 'elecs': array([0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3.,
#        3., 1., 2., 0.]), 'action': array([0, 0, 3, 2, 0]), 'missed_cyc': 0, 'stim_id': 4383, 'simulated': False, 'comment': 'none'}
# State: [-1.  0.  0.  0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.4,  1. ,  2. ,  4.1,  4.7,  5.1,  6.5,  8.3,  8.6,  9. , 10.3,
#        11.1, 11.9, 14. , 14.6, 14.9, 16.4, 18.2, 18.5, 18.8]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4384, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.2,  1.2,  3.4,  3.9,  4.3,  5.7,  7.5,  7.8,  8.2,  9.5, 10.3,
#        11.1, 13.2, 13.8, 14.1, 15.6, 17.4, 17.7, 18.1, 19.4]), 'elecs': array([0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1.,
#        2., 0., 2.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4385, 'simulated': False, 'comment': 'none'}
# State: [-1.          0.         -0.29664794  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 2 1 1]
# Info: {'spikes': array([ 0.2,  2.5,  2.9,  3.4,  4.7,  6.5,  6.8,  7.3,  8.6,  9.3, 10.2,
#        12.3, 12.9, 13.2, 14.7, 16.5, 16.8, 17.2, 18.5, 19.3]), 'elecs': array([0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2.,
#        0., 2., 0.]), 'action': array([0, 0, 2, 1, 1]), 'missed_cyc': 0, 'stim_id': 4386, 'simulated': False, 'comment': 'none'}
# State: [-1.         -0.30331502 -0.12649111  0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 1.4,  1.9,  2.4,  3.7,  5.5,  5.8,  6.3,  7.6,  8.3,  9.2, 11.3,
#        11.9, 12.3, 13.7, 15.5, 15.8, 16.2, 17.5, 18.3, 19.1]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4387, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.14142136 -0.14142136  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 0 2 3]
# Info: {'spikes': array([ 0.9,  1.4,  1.8,  3.2,  5. ,  5.3,  5.7,  7. ,  7.8,  8.6, 10.7,
#        11.3, 11.6, 13.1, 14.9, 15.2, 15.6, 16.9, 17.7, 18.5]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 0, 2, 3]), 'missed_cyc': 0, 'stim_id': 4388, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.14142136 -0.12649111  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 4 0 4]
# Info: {'spikes': array([ 0.3,  0.9,  1.2,  2.7,  4.5,  4.8,  5.2,  6.5,  7.3,  8.1, 10.2,
#        10.8, 11.1, 12.6, 14.4, 14.7, 15.1, 16.4, 17.2, 18. ]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 4, 0, 4]), 'missed_cyc': 0, 'stim_id': 4389, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.15491933 -0.10954451  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 1 1 4]
# Info: {'spikes': array([ 0. ,  0.2,  1.8,  3.6,  3.9,  4.4,  5.7,  6.4,  7.3,  9.4, 10. ,
#        10.4, 11.8, 13.6, 13.9, 14.3, 15.6, 16.4, 17.2, 19.3, 19.9]), 'elecs': array([2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2.,
#        0., 0., 1., 2.]), 'action': array([0, 0, 1, 1, 4]), 'missed_cyc': 0, 'stim_id': 4390, 'simulated': False, 'comment': 'none'}
# State: [ 0.         -0.08944272  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 2 1 4]
# Info: {'spikes': array([ 1.4,  3.2,  3.5,  3.9,  5.2,  6. ,  6.8,  8.9,  9.5,  9.8, 11.3,
#        13.1, 13.4, 13.8, 15.1, 15.9, 16.7, 18.8, 19.4, 19.7]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 2, 1, 4]), 'missed_cyc': 0, 'stim_id': 4391, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 4 4 1]
# Info: {'spikes': array([ 0.8,  2.6,  2.9,  3.3,  4.6,  5.4,  6.2,  8.3,  8.9,  9.2, 10.7,
#        12.5, 12.8, 13.2, 14.5, 15.3, 16.1, 18.2, 18.8, 19.1]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 4, 4, 1]), 'missed_cyc': 0, 'stim_id': 4392, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 2 2 1]
# Info: {'spikes': array([ 0.2,  1.9,  2.2,  2.6,  3.9,  4.7,  5.5,  7.6,  8.2,  8.5, 10. ,
#        11.8, 12.1, 12.5, 13.8, 14.6, 15.4, 17.5, 18.1, 18.5, 19.9]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3., 3.]), 'action': array([0, 0, 2, 2, 1]), 'missed_cyc': 0, 'stim_id': 4393, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 1 3 3]
# Info: {'spikes': array([ 1.4,  1.7,  2.1,  3.4,  4.2,  5. ,  7.1,  7.6,  8. ,  9.4, 11.2,
#        11.5, 11.9, 13.2, 14. , 14.8, 16.9, 17.5, 17.9, 19.3]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 1, 3, 3]), 'missed_cyc': 0, 'stim_id': 4394, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 4 1 2]
# Info: {'spikes': array([ 0.3,  0.6,  1.2,  2.5,  3.1,  4.1,  6.2,  6.8,  7.1,  8.6, 10.4,
#        10.7, 11.1, 12.4, 13.2, 14. , 16.1, 16.6, 17. , 18.4]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 4, 1, 2]), 'missed_cyc': 0, 'stim_id': 4395, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 4 2]
# Info: {'spikes': array([ 0.4,  1.7,  2.2,  3.3,  5.4,  6. ,  6.4,  7.8,  9.6,  9.9, 10.2,
#        11.5, 12.4, 13.1, 15.2, 15.8, 16.1, 17.6, 19.4, 19.7]), 'elecs': array([0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3.,
#        3., 1., 2.]), 'action': array([0, 0, 3, 4, 2]), 'missed_cyc': 0, 'stim_id': 4396, 'simulated': False, 'comment': 'none'}
# State: [-1.  0.  0.  0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 2 0 1]
# Info: {'spikes': array([ 0.6,  1.6,  2.2,  4.3,  5. ,  5.2,  6.8,  8.6,  8.9,  9.2, 10.5,
#        11.4, 12.1, 14.2, 14.8, 15.2, 16.6, 18.4, 18.7, 19.1]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0.]), 'action': array([0, 0, 2, 0, 1]), 'missed_cyc': 0, 'stim_id': 4397, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 2 2 2]
# Info: {'spikes': array([ 0. ,  0.5,  1.6,  3.7,  4.3,  4.6,  6.1,  7.9,  8.2,  8.6,  9.9,
#        10.7, 11.5, 13.6, 14.2, 14.5, 16. , 17.8, 18.1, 18.5, 19.8]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0., 2.]), 'action': array([0, 0, 2, 2, 2]), 'missed_cyc': 0, 'stim_id': 4398, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 2 1 4]
# Info: {'spikes': array([ 0. ,  0.8,  3. ,  3.5,  4. ,  5.3,  7.1,  7.4,  7.8,  9.1,  9.9,
#        10.7, 12.8, 13.4, 13.8, 15.2, 17. , 17.3, 17.7, 19. , 19.8]), 'elecs': array([0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1.,
#        2., 0., 2., 0.]), 'action': array([0, 0, 2, 1, 4]), 'missed_cyc': 0, 'stim_id': 4399, 'simulated': False, 'comment': 'none'}
# State: [-1.          0.         -0.29664794  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 4 4 4]
# Info: {'spikes': array([ 0.2,  2.3,  2.9,  3.2,  4.7,  6.5,  6.8,  7.2,  8.5,  9.3, 10.1,
#        12.2, 12.8, 13.1, 14.6, 16.4, 16.7, 17.1, 18.4, 19.2]), 'elecs': array([0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2.,
#        0., 2., 0.]), 'action': array([0, 0, 4, 4, 4]), 'missed_cyc': 0, 'stim_id': 4400, 'simulated': False, 'comment': 'none'}
# State: [-1.         -0.28982753 -0.15491933  0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 2 1 1]
# Info: {'spikes': array([ 1.4,  1.8,  2.4,  3.6,  5.4,  5.7,  6.2,  7.5,  8.2,  9.1, 11.2,
#        11.8, 12.2, 13.6, 15.4, 15.7, 16.1, 17.4, 18.2, 19. ]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 2, 1, 1]), 'missed_cyc': 0, 'stim_id': 4401, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.12649111 -0.15491933  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 4 4 4]
# Info: {'spikes': array([ 0.8,  1.4,  1.7,  3.2,  5. ,  5.3,  5.7,  7. ,  7.8,  8.6, 10.7,
#        11.3, 11.6, 13.1, 14.9, 15.2, 15.6, 16.9, 17.7, 18.5]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 4, 4, 4]), 'missed_cyc': 0, 'stim_id': 4402, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.15491933 -0.10954451  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 4 2 4]
# Info: {'spikes': array([ 0.3,  0.9,  1.2,  2.7,  4.5,  4.8,  5.3,  6.6,  7.3,  8.2, 10.3,
#        10.9, 11.2, 12.7, 14.5, 14.8, 15.2, 16.5, 17.3, 18.1]), 'elecs': array([1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0.,
#        2., 0., 0.]), 'action': array([0, 0, 4, 2, 4]), 'missed_cyc': 0, 'stim_id': 4403, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.15491933 -0.10954451  0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 0 3 1]
# Info: {'spikes': array([ 0.4,  0.8,  2.2,  4. ,  4.3,  4.8,  6.1,  6.8,  7.7,  9.8, 10.3,
#        10.7, 12.1, 13.9, 14.2, 14.7, 16. , 16.7, 17.6, 19.7]), 'elecs': array([2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2.,
#        0., 0., 1.]), 'action': array([0, 0, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 4404, 'simulated': False, 'comment': 'none'}
# State: [ 0.         -0.12649111  0.          0.        ], Reward: 6
# -----------------------------
# Stimulate with action: [0 0 3 2 3]
# Info: {'spikes': array([ 0.3,  1.3,  3.1,  3.4,  4. ,  5.3,  5.9,  6.9,  9. ,  9.6, 10. ,
#        11.4, 13.2, 13.5, 14. , 15.3, 16. , 16.9, 19. , 19.6, 19.9]), 'elecs': array([3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0.,
#        0., 1., 2., 3.]), 'action': array([0, 0, 3, 2, 3]), 'missed_cyc': 0, 'stim_id': 4405, 'simulated': False, 'comment': 'none'}
# State: [0.5 0.  0.  0. ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 1 0 3]
# Info: {'spikes': array([ 0.9,  2.7,  3. ,  3.6,  4.9,  5.5,  6.5,  8.6,  9.1,  9.6, 10.9,
#        12.7, 13. , 13.5, 14.8, 15.5, 16.4, 18.5, 19.1, 19.5]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 1, 0, 3]), 'missed_cyc': 0, 'stim_id': 4406, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 4 2 1]
# Info: {'spikes': array([ 0.6,  2.4,  2.7,  3.1,  4.4,  5.2,  6. ,  8.1,  8.7,  9. , 10.5,
#        12.3, 12.6, 13. , 14.3, 15.1, 15.9, 18. , 18.6, 18.9]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3.]), 'action': array([0, 0, 4, 2, 1]), 'missed_cyc': 0, 'stim_id': 4407, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 0 1 1]
# Info: {'spikes': array([ 0.1,  1.9,  2.2,  2.6,  3.9,  4.7,  5.5,  7.6,  8.2,  8.5, 10. ,
#        11.8, 12.1, 12.5, 13.8, 14.6, 15.4, 17.5, 18. , 18.4, 19.8]), 'elecs': array([3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0.,
#        1., 2., 3., 3.]), 'action': array([0, 0, 0, 1, 1]), 'missed_cyc': 0, 'stim_id': 4408, 'simulated': False, 'comment': 'none'}
# State: [ 0.5         0.         -0.10954451  0.        ], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 3 3 2]
# Info: {'spikes': array([ 0.8,  1.1,  1.8,  3.1,  3.6,  4.7,  6.8,  7.4,  7.7,  9.2, 11. ,
#        11.3, 11.7, 13. , 13.8, 14.6, 16.7, 17.3, 17.6, 19.1]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 3, 3, 2]), 'missed_cyc': 0, 'stim_id': 4409, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 4 2 0]
# Info: {'spikes': array([ 0.3,  0.6,  1.1,  2.4,  3.1,  4. ,  6.1,  6.7,  7. ,  8.5, 10.3,
#        10.6, 11. , 12.3, 13.1, 13.9, 16. , 16.6, 16.9, 18.4]), 'elecs': array([1., 2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1.,
#        2., 3., 3.]), 'action': array([0, 0, 4, 2, 0]), 'missed_cyc': 0, 'stim_id': 4410, 'simulated': False, 'comment': 'none'}
# State: [-0.5        -0.10954451  0.          0.        ], Reward: 7
# -----------------------------
# Stimulate with action: [0 0 3 2 1]
# Info: {'spikes': array([ 0.1,  0.3,  1.6,  2.6,  3.2,  5.3,  5.8,  6.2,  7.6,  9.4,  9.7,
#        10.1, 11.4, 12.2, 13. , 15.1, 15.7, 16. , 17.5, 19.3, 19.6]), 'elecs': array([2., 0., 2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2.,
#        3., 3., 1., 2.]), 'action': array([0, 0, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 4411, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------
# Stimulate with action: [0 0 4 3 4]
# Info: {'spikes': array([ 0.9,  1.7,  2.5,  4.6,  5.2,  5.6,  7. ,  8.8,  9.1,  9.5, 10.8,
#        11.6, 12.4, 14.5, 15.1, 15.4, 16.9, 18.7, 19. , 19.4]), 'elecs': array([2., 0., 0., 1., 2., 3., 3., 1., 2., 0., 2., 0., 0., 1., 2., 3., 3.,
#        1., 2., 0.]), 'action': array([0, 0, 4, 3, 4]), 'missed_cyc': 0, 'stim_id': 4412, 'simulated': False, 'comment': 'none'}
# State: [0. 0. 0. 0.], Reward: 8
# -----------------------------

# %%
print(f"Average reward: {total_reward/action_count}")
# Out:
# Average reward: 6.41
